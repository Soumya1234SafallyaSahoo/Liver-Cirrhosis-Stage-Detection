# %% [markdown]
# <a href="https://colab.research.google.com/github/Soumya1234SafallyaSahoo/Liver-Cirrhosis-Stage-Detection/blob/main/Liver_Cirrhosis_Stage_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    N_Days Status     Drug    Age Sex Ascites Hepatomegaly Spiders Edema  \
# 0    2221      C  Placebo  18499   F       N            Y       N     N
# 1    1230      C  Placebo  19724   M       Y            N       Y     N
# 2    4184      C  Placebo  11839   F       N            N       N     N
# 3    2090      D  Placebo  16467   F       N            N       N     N
# 4    2105      D  Placebo  21699   F       N            Y       N     N
#
#    Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  Tryglicerides  \
# 0        0.5        149.0     4.04   227.0     598.0   52.70           57.0
# 1        0.5        219.0     3.93    22.0     663.0   45.00           75.0
# 2        0.5        320.0     3.54    51.0    1243.0  122.45           80.0
# 3        0.7        255.0     3.74    23.0    1024.0   77.50           58.0
# 4        1.9        486.0     3.54    74.0    1052.0  108.50          109.0
#
#    Platelets  Prothrombin  Stage
# 0      256.0          9.9      1
# ...

# %% [markdown]
# Checking for missing values

# %%
df.isnull().sum()
# Out:
# N_Days           0
# Status           0
# Drug             0
# Age              0
# Sex              0
# Ascites          0
# Hepatomegaly     0
# Spiders          0
# Edema            0
# Bilirubin        0
# Cholesterol      0
# Albumin          0
# Copper           0
# Alk_Phos         0
# SGOT             0
# Tryglicerides    0
# Platelets        0
# Prothrombin      0
# Stage            0
# dtype: int64

# %% [markdown]
# No missing values,Now checking data types of each column

# %%
df.dtypes
# Out:
# N_Days             int64
# Status            object
# Drug              object
# Age                int64
# Sex               object
# Ascites           object
# Hepatomegaly      object
# Spiders           object
# Edema             object
# Bilirubin        float64
# Cholesterol      float64
# Albumin          float64
# Copper           float64
# Alk_Phos         float64
# SGOT             float64
# Tryglicerides    float64
# Platelets        float64
# Prothrombin      float64
# Stage              int64
# dtype: object

# %% [markdown]
# these 7 columns are categorical and need encoding:
#
# ['Status', 'Drug', 'Sex', 'Ascites', 'Hepatomegaly', 'Spiders', 'Edema']

# %% [markdown]
# Label encode the categorical columns

# %%
from sklearn.preprocessing import LabelEncoder

label_cols = ['Status', 'Drug', 'Sex', 'Ascites', 'Hepatomegaly', 'Spiders', 'Edema']
le = LabelEncoder()

for col in label_cols:
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    N_Days  Status  Drug    Age  Sex  Ascites  Hepatomegaly  Spiders  Edema  \
# 0    2221       0     1  18499    0        0             1        0      0
# 1    1230       0     1  19724    1        1             0        1      0
# 2    4184       0     1  11839    0        0             0        0      0
# 3    2090       2     1  16467    0        0             0        0      0
# 4    2105       2     1  21699    0        0             1        0      0
#
#    Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  Tryglicerides  \
# 0        0.5        149.0     4.04   227.0     598.0   52.70           57.0
# 1        0.5        219.0     3.93    22.0     663.0   45.00           75.0
# 2        0.5        320.0     3.54    51.0    1243.0  122.45           80.0
# 3        0.7        255.0     3.74    23.0    1024.0   77.50           58.0
# 4        1.9        486.0     3.54    74.0    1052.0  108.50          109.0
#
#    Platelets  Prothrombin  Stage
# ...

# %% [markdown]
#  Splitting the data into features (X) and target (y)
# X → all the input features
#
# y → the target column, which is Stage (what we want to predict)

# %%
X = df.drop("Stage", axis=1) #since stage is output so I removed it from the input feature
y = df["Stage"]

# %% [markdown]
# Split the data for training and testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
X_train.shape, X_test.shape
# Out:
# ((20000, 18), (5000, 18))

# %% [markdown]
# 20,000 training samples
#
# 5,000 testing samples

# %% [markdown]
#  Train the Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# Make predictions on the test data

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# Evaluate the model

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1546   79   28]
#  [  50 1614   24]
#  [  14   42 1603]]
#               precision    recall  f1-score   support
#
#            1       0.96      0.94      0.95      1653
#            2       0.93      0.96      0.94      1688
#            3       0.97      0.97      0.97      1659
#
#     accuracy                           0.95      5000
#    macro avg       0.95      0.95      0.95      5000
# weighted avg       0.95      0.95      0.95      5000

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9526

# %% [markdown]
# Let's predict

# %%
y_pred = model.predict(X_test)

# %%
print(y_pred)
# Out:
# [3 1 1 ... 1 1 2]
